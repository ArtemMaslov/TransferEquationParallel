# %%
import pandas
import numpy
import matplotlib.pyplot as plt
import math

# %%
data = pandas.read_csv("result.txt", sep = " ")
a = 1
PeriodX = 1

def Reference(x, t):
    return numpy.sin(2 * math.pi * (x - a * t) / PeriodX)

ref = Reference(data["x"], data["t"])
plt.plot(data["x"], data["u"], label = "mod")
plt.plot(data["x"], ref, label = "ref")
plt.legend()
plt.grid()
plt.show()

plt.plot(data["x"], numpy.log10(numpy.abs(ref - data["u"])), label = "log|res|")
plt.legend()
plt.grid()
plt.show()
# Out:
# /home/artem/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
